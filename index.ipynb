# %% [markdown]
# # Network Dynamics: Node Centrality - Lab
#
# ## Introduction
# In this lab, we shall put the node centrality measures in to practice to analyze the character interactions in graph structure from the popular series of novels called ""A Song of Ice and Fire" by George R. R. Martin. The of famous HBO series "Game of Thrones" is derived from this saga. In this lab, we shall calculate different centrality measures to identify the the importance of characters as the story progresses.
#
#
# ## Objectives
# You will be able to:
# - Understand and explain network centrality and its importance in graph analysis
# - Understand and calculate Degree, Closeness, Betweenness and Eigenvector centrality measures
# - Describe the use case for several centrality measures

# %% [markdown]
# ## ASIOF (A Song of Ice and Fire) Character Interaction Graph Data
#
# A. J. Beveridge, and J. Shan  created a network from books "A song of ice and fire" by extracting relationships between characters of the story. [The dataset is available at Github](https://github.com/mathbeveridge/asoiaf)
# as an interaction network which was built as
# > Parse the text and build a graph by connecting (creating an edge) two characters (nodes of the graph) whenever their names appear within 15 words. The edge weight corresponds to the number of interactions.
#
# <img src="parse.png" width=300>
#
# The datasets have been made available for you in the repo. You are encouraged to [visit A. J. Beveridge's blog](https://networkofthrones.wordpress.com) to see how this dataset is created, and different network analysis activities which are being performed with this dataset. The image you see below, has been created using same datasets. The blog gives you information on this and more experiments. For this lab, we shall focus more on graph analysis than visualizations.
#
# <img src="got.png" width=800>
#
# Let's get on with it.

# %% [markdown]
# ## Load necessary libraries
#
# - Let's give you a head start by loading the libraries that you might need for this experiment.

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ##  Load the dataset
#
# The dataset is available for all 5 books, with two CSV files for each book. One contains nodes data as adjacency matrix and other carries edges data as edge list, e.g. for book 1, `asoiaf-book1-edges.csv` and `asoiaf-book1-nodes.csv`. So we have 10 files in total.
#
# - Read edge data for all books into pandas dataframe:  book1_df .. book5_df.
#
# How about using a for loop to do this in one go - optional.

# %%
# Load edges into dataframes
edge_dfs = []
for i in range(1,6):
    df = pd.read_csv(f'asiof\\asoiaf-book{i}-edges.csv')
    edge_dfs.append(df)
edge_dfs[1].head()
# Out:
#               Source             Target        Type  weight  book
# 0  Aegon-I-Targaryen       Harren-Hoare  Undirected       4   2.0
# 1  Aegon-I-Targaryen                Nan  Undirected       3   2.0
# 2  Aegon-I-Targaryen  Rhaenys-Targaryen  Undirected       4   2.0
# 3  Aegon-I-Targaryen   Tyrion-Lannister  Undirected       3   2.0
# 4  Aegon-I-Targaryen  Visenya-Targaryen  Undirected       3   2.0

# %% [markdown]
# ## Create Empty graph instances for each book

# %%
# Create empty instances for each book above
graphs = []
for i in range(0,5):
    graphs.append(nx.Graph())
type(graphs[0])
# Out:
# networkx.classes.graph.Graph

# %% [markdown]
# ## Create Graph
# - Read the edge lists from the dataframes above into relevant graphs.
# - inspect the contents of graph to get an idea about the data structures contained within

# %%
list(edge_dfs[1].iterrows())[0]
# Out:
# (0, Source    Aegon-I-Targaryen
#  Target         Harren-Hoare
#  Type             Undirected
#  weight                    4
#  book                      2
#  Name: 0, dtype: object)

# %%
# Read edge lists into dataframes
for i in range(0,5):
    df = edge_dfs[i]
    for row in df.iterrows():
        data = row[1]
        #print(data[0], data[1],data[3], data[4])
        graphs[i].add_edge(data[0], data[1], weight = data[3])
    print(graphs[i].edges(data=True))
# Out:
# [('Addam-Marbrand', 'Jaime-Lannister', {'weight': 3}), ('Addam-Marbrand', 'Tywin-Lannister', {'weight': 6}), ('Jaime-Lannister', 'Aerys-II-Targaryen', {'weight': 5}), ('Jaime-Lannister', 'Barristan-Selmy', {'weight': 4}), ('Jaime-Lannister', 'Brynden-Tully', {'weight': 7}), ('Jaime-Lannister', 'Catelyn-Stark', {'weight': 9}), ('Jaime-Lannister', 'Cersei-Lannister', {'weight': 16}), ('Jaime-Lannister', 'Eddard-Stark', {'weight': 27}), ('Jaime-Lannister', 'Edmure-Tully', {'weight': 4}), ('Jaime-Lannister', 'Galbart-Glover', {'weight': 3}), ('Jaime-Lannister', 'Gregor-Clegane', {'weight': 3}), ('Jaime-Lannister', 'Harys-Swyft', {'weight': 3}), ('Jaime-Lannister', 'Joffrey-Baratheon', {'weight': 12}), ('Jaime-Lannister', 'Jon-Arryn', {'weight': 5}), ('Jaime-Lannister', 'Jory-Cassel', {'weight': 4}), ('Jaime-Lannister', 'Kevan-Lannister', {'weight': 4}), ('Jaime-Lannister', 'Loras-Tyrell', {'weight': 3}), ('Jaime-Lannister', 'Lysa-Arryn', {'weight': 6}), ('Jaime-Lannister', 'Petyr-Baelish', {'weight': 7}), ('Jaime-Lannister', 'Renly-Baratheon', {'weight': 4}), ('Jaime-Lannister', 'Rickard-Karstark', {'weight': 3}), ('Jaime-Lannister', 'Robb-Stark', {'weight': 9}), ('Jaime-Lannister', 'Robert-Baratheon', {'weight': 24}), ('Jaime-Lannister', 'Rodrik-Cassel', {'weight': 3}), ('Jaime-Lannister', 'Sandor-Clegane', {'weight': 12}), ('Jaime-Lannister', 'Sansa-Stark', {'weight': 3}), ('Jaime-Lannister', 'Tyrion-Lannister', {'weight': 36}), ('Jaime-Lannister', 'Tywin-Lannister', {'weight': 16}), ('Jaime-Lannister', 'Varys', {'weight': 3}), ('Jaime-Lannister', 'Wyl-(guard)', {'weight': 3}), ('Tywin-Lannister', 'Bronn', {'weight': 4}), ('Tywin-Lannister', 'Brynden-Tully', {'weight': 3}), ('Tywin-Lannister', 'Catelyn-Stark', {'weight': 7}), ('Tywin-Lannister', 'Cersei-Lannister', {'weight': 10}), ('Tywin-Lannister', 'Eddard-Stark', {'weight': 18}), ('Tywin-Lannister', 'Gregor-Clegane', {'weight': 6}), ('Tywin-Lannister', 'Joffrey-Baratheon', {'weight': 3}), ('Tywin-Lannister', 'Jon-Umber-(Greatjon)', {'weight': 3}), ('Tywin-Lannister', 'Kevan-Lannister', {'weight': 9}), ('Tywin-Lannister', 'Marq-Piper', {'weight': 3}), ('Tywin-Lannister', 'Pycelle', {'weight': 4}), ('Tywin-Lannister', 'Rhaegar-Targaryen', {'weight': 4}), ('Tywin-Lannister', 'Robb-Stark', {'weight': 9}), ('Tywin-Lannister', 'Robert-Baratheon', {'weight': 13}), ('Tywin-Lannister', 'Roose-Bolton', {'weight': 4}), ('Tywin-Lannister', 'Stannis-Baratheon', {'weight': 4}), ('Tywin-Lannister', 'Theon-Greyjoy', {'weight': 3}), ('Tywin-Lannister', 'Tyrion-Lannister', {'weight': 40}), ('Tywin-Lannister', 'Varys', {'weight': 4}), ('Tywin-Lannister', 'Walder-Frey', {'weight': 8}), ('Aegon-I-Targaryen', 'Daenerys-Targaryen', {'weight': 5}), ('Aegon-I-Targaryen', 'Eddard-Stark', {'weight': 4}), ('Daenerys-Targaryen', 'Aggo', {'weight': 11}), ('Daenerys-Targaryen', 'Cohollo', {'weight': 7}), ('Daenerys-Targaryen', 'Doreah', {'weight': 15}), ('Daenerys-Targaryen', 'Drogo', {'weight': 101}), ('Daenerys-Targaryen', 'Eddard-Stark', {'weight': 5}), ('Daenerys-Targaryen', 'Eroeh', {'weight': 5}), ('Daenerys-Targaryen', 'Haggo', {'weight': 12}), ('Daenerys-Targaryen', 'Illyrio-Mopatis', {'weight': 24}), ('Daenerys-Targaryen', 'Irri', {'weight': 25}), ('Daenerys-Targaryen', 'Jhiqui', {'weight': 26}), ('Daenerys-Targaryen', 'Jhogo', {'weight': 17}), ('Daenerys-Targaryen', 'Jorah-Mormont', {'weight': 75}), ('Daenerys-Targaryen', 'Mirri-Maz-Duur', {'weight': 31}), ('Daenerys-Targaryen', 'Qotho', {'weight': 18}), ('Daenerys-Targaryen', 'Quaro', {'weight': 5}), ('Daenerys-Targaryen', 'Rakharo', {'weight': 4}), ('Daenerys-Targaryen', 'Rhaegar-Targaryen', {'weight': 4}), ('Daenerys-Targaryen', 'Robert-Baratheon', {'weight': 11}), ('Daenerys-Targaryen', 'Varys', {'weight': 5}), ('Daenerys-Targaryen', 'Viserys-Targaryen', {'weight': 37}), ('Eddard-Stark', 'Aerys-II-Targaryen', {'weight': 10}), ('Eddard-Stark', 'Alyn', {'weight': 11}), ('Eddard-Stark', 'Arya-Stark', {'weight': 30}), ('Eddard-Stark', 'Balon-Gre ...
# [('Aegon-I-Targaryen', 'Harren-Hoare', {'weight': 4}), ('Aegon-I-Targaryen', 'Nan', {'weight': 3}), ('Aegon-I-Targaryen', 'Rhaenys-Targaryen', {'weight': 4}), ('Aegon-I-Targaryen', 'Tyrion-Lannister', {'weight': 3}), ('Aegon-I-Targaryen', 'Visenya-Targaryen', {'weight': 3}), ('Harren-Hoare', 'Arya-Stark', {'weight': 7}), ('Harren-Hoare', 'Nan', {'weight': 5}), ('Nan', 'Arya-Stark', {'weight': 5}), ('Nan', 'Bran-Stark', {'weight': 7}), ('Nan', 'Jon-Snow', {'weight': 4}), ('Rhaenys-Targaryen', 'Visenya-Targaryen', {'weight': 3}), ('Tyrion-Lannister', 'Aerys-II-Targaryen', {'weight': 3}), ('Tyrion-Lannister', 'Alayaya', {'weight': 3}), ('Tyrion-Lannister', 'Allar-Deem', {'weight': 4}), ('Tyrion-Lannister', 'Alliser-Thorne', {'weight': 8}), ('Tyrion-Lannister', 'Arya-Stark', {'weight': 4}), ('Tyrion-Lannister', 'Ballabar', {'weight': 12}), ('Tyrion-Lannister', 'Balon-Swann', {'weight': 8}), ('Tyrion-Lannister', 'Boros-Blount', {'weight': 8}), ('Tyrion-Lannister', 'Bronn', {'weight': 40}), ('Tyrion-Lannister', 'Catelyn-Stark', {'weight': 10}), ('Tyrion-Lannister', 'Cersei-Lannister', {'weight': 87}), ('Tyrion-Lannister', 'Chataya', {'weight': 6}), ('Tyrion-Lannister', 'Chella', {'weight': 3}), ('Tyrion-Lannister', 'Cleos-Frey', {'weight': 13}), ('Tyrion-Lannister', 'Cortnay-Penrose', {'weight': 3}), ('Tyrion-Lannister', 'Dontos-Hollard', {'weight': 4}), ('Tyrion-Lannister', 'Doran-Martell', {'weight': 3}), ('Tyrion-Lannister', 'Eddard-Stark', {'weight': 12}), ('Tyrion-Lannister', 'Gyles-Rosby', {'weight': 3}), ('Tyrion-Lannister', 'Hallyne', {'weight': 5}), ('Tyrion-Lannister', 'High-Septon-(fat_one)', {'weight': 4}), ('Tyrion-Lannister', 'High-Septon-(Tyrions)', {'weight': 4}), ('Tyrion-Lannister', 'Jacelyn-Bywater', {'weight': 16}), ('Tyrion-Lannister', 'Jaime-Lannister', {'weight': 25}), ('Tyrion-Lannister', 'Janos-Slynt', {'weight': 26}), ('Tyrion-Lannister', 'Joffrey-Baratheon', {'weight': 92}), ('Tyrion-Lannister', 'Lancel-Lannister', {'weight': 18}), ('Tyrion-Lannister', 'Loras-Tyrell', {'weight': 8}), ('Tyrion-Lannister', 'Lysa-Arryn', {'weight': 5}), ('Tyrion-Lannister', 'Mandon-Moore', {'weight': 16}), ('Tyrion-Lannister', 'Meryn-Trant', {'weight': 7}), ('Tyrion-Lannister', 'Myrcella-Baratheon', {'weight': 8}), ('Tyrion-Lannister', 'Osmund-Kettleblack', {'weight': 7}), ('Tyrion-Lannister', 'Petyr-Baelish', {'weight': 41}), ('Tyrion-Lannister', 'Podrick-Payne', {'weight': 13}), ('Tyrion-Lannister', 'Preston-Greenfield', {'weight': 3}), ('Tyrion-Lannister', 'Pycelle', {'weight': 21}), ('Tyrion-Lannister', 'Renly-Baratheon', {'weight': 14}), ('Tyrion-Lannister', 'Robb-Stark', {'weight': 18}), ('Tyrion-Lannister', 'Robert-Baratheon', {'weight': 10}), ('Tyrion-Lannister', 'Sandor-Clegane', {'weight': 13}), ('Tyrion-Lannister', 'Sansa-Stark', {'weight': 31}), ('Tyrion-Lannister', 'Shae', {'weight': 30}), ('Tyrion-Lannister', 'Shagga', {'weight': 15}), ('Tyrion-Lannister', 'Stannis-Baratheon', {'weight': 39}), ('Tyrion-Lannister', 'Tanda-Stokeworth', {'weight': 4}), ('Tyrion-Lannister', 'Timett', {'weight': 10}), ('Tyrion-Lannister', 'Tommen-Baratheon', {'weight': 10}), ('Tyrion-Lannister', 'Tysha', {'weight': 4}), ('Tyrion-Lannister', 'Tywin-Lannister', {'weight': 6}), ('Tyrion-Lannister', 'Varys', {'weight': 63}), ('Tyrion-Lannister', 'Vylarr', {'weight': 6}), ('Aegon-V-Targaryen', 'Aemon-Targaryen-(Maester-Aemon)', {'weight': 3}), ('Aemon-Targaryen-(Maester-Aemon)', 'Daeron-II-Targaryen', {'weight': 3}), ('Aemon-Targaryen-(Maester-Aemon)', 'Jeor-Mormont', {'weight': 9}), ('Aemon-Targaryen-(Maester-Aemon)', 'Jon-Snow', {'weight': 11}), ('Aemon-Targaryen-(Maester-Aemon)', 'Maekar-I-Targaryen', {'weight': 3}), ('Aemon-Targaryen-(Maester-Aemon)', 'Samwell-Tarly', {'weight': 5}), ('Jeor-Mormont', 'Alliser-Thorne', {'weight': 3}), ('Jeor-Mormont', 'Benjen-Stark', {'weight': 5}), ('Jeor-Mormont', 'Craster', {'weight': 19}), ('Jeor-Mormont', 'Eddison-Tollett', {'weight': 4}), ('Jeor-Mormont', 'Grenn', {'weight': 3}), ('Jeor-Mormont', ...
# [('Addam-Marbrand', 'Gyles-Rosby', {'weight': 3}), ('Addam-Marbrand', 'Jaime-Lannister', {'weight': 3}), ('Addam-Marbrand', 'Jalabhar-Xho', {'weight': 3}), ('Addam-Marbrand', 'Joffrey-Baratheon', {'weight': 3}), ('Addam-Marbrand', 'Kevan-Lannister', {'weight': 3}), ('Addam-Marbrand', 'Oberyn-Martell', {'weight': 3}), ('Addam-Marbrand', 'Tyrion-Lannister', {'weight': 7}), ('Addam-Marbrand', 'Varys', {'weight': 4}), ('Gyles-Rosby', 'Jalabhar-Xho', {'weight': 4}), ('Jaime-Lannister', 'Aemon-Targaryen-(Dragonknight)', {'weight': 3}), ('Jaime-Lannister', 'Aerys-II-Targaryen', {'weight': 22}), ('Jaime-Lannister', 'Amory-Lorch', {'weight': 3}), ('Jaime-Lannister', 'Arya-Stark', {'weight': 10}), ('Jaime-Lannister', 'Balon-Swann', {'weight': 5}), ('Jaime-Lannister', 'Barristan-Selmy', {'weight': 4}), ('Jaime-Lannister', 'Boros-Blount', {'weight': 6}), ('Jaime-Lannister', 'Brienne-of-Tarth', {'weight': 87}), ('Jaime-Lannister', 'Catelyn-Stark', {'weight': 19}), ('Jaime-Lannister', 'Cersei-Lannister', {'weight': 35}), ('Jaime-Lannister', 'Cleos-Frey', {'weight': 25}), ('Jaime-Lannister', 'Eddard-Stark', {'weight': 6}), ('Jaime-Lannister', 'Edmure-Tully', {'weight': 4}), ('Jaime-Lannister', 'Elia-Martell', {'weight': 4}), ('Jaime-Lannister', 'Elmar-Frey', {'weight': 6}), ('Jaime-Lannister', 'Gerold-Hightower', {'weight': 4}), ('Jaime-Lannister', 'Gregor-Clegane', {'weight': 7}), ('Jaime-Lannister', 'Hoster-Tully', {'weight': 4}), ('Jaime-Lannister', 'Joffrey-Baratheon', {'weight': 21}), ('Jaime-Lannister', 'Lem', {'weight': 6}), ('Jaime-Lannister', 'Loras-Tyrell', {'weight': 24}), ('Jaime-Lannister', 'Lysa-Arryn', {'weight': 3}), ('Jaime-Lannister', 'Meryn-Trant', {'weight': 9}), ('Jaime-Lannister', 'Oberyn-Martell', {'weight': 3}), ('Jaime-Lannister', 'Osmund-Kettleblack', {'weight': 5}), ('Jaime-Lannister', 'Qyburn', {'weight': 21}), ('Jaime-Lannister', 'Renly-Baratheon', {'weight': 9}), ('Jaime-Lannister', 'Rickard-Karstark', {'weight': 4}), ('Jaime-Lannister', 'Robb-Stark', {'weight': 17}), ('Jaime-Lannister', 'Robert-Baratheon', {'weight': 18}), ('Jaime-Lannister', 'Robin-Ryger', {'weight': 9}), ('Jaime-Lannister', 'Roose-Bolton', {'weight': 17}), ('Jaime-Lannister', 'Rorge', {'weight': 9}), ('Jaime-Lannister', 'Sansa-Stark', {'weight': 9}), ('Jaime-Lannister', 'Shagwell', {'weight': 4}), ('Jaime-Lannister', 'Stannis-Baratheon', {'weight': 6}), ('Jaime-Lannister', 'Thoros-of-Myr', {'weight': 3}), ('Jaime-Lannister', 'Tommen-Baratheon', {'weight': 10}), ('Jaime-Lannister', 'Tyrion-Lannister', {'weight': 33}), ('Jaime-Lannister', 'Tywin-Lannister', {'weight': 16}), ('Jaime-Lannister', 'Urswyck', {'weight': 11}), ('Jaime-Lannister', 'Vargo-Hoat', {'weight': 16}), ('Jaime-Lannister', 'Varys', {'weight': 5}), ('Jaime-Lannister', 'Walton', {'weight': 18}), ('Joffrey-Baratheon', 'Aerys-II-Targaryen', {'weight': 6}), ('Joffrey-Baratheon', 'Arya-Stark', {'weight': 10}), ('Joffrey-Baratheon', 'Balon-Swann', {'weight': 5}), ('Joffrey-Baratheon', 'Beric-Dondarrion', {'weight': 3}), ('Joffrey-Baratheon', 'Bran-Stark', {'weight': 3}), ('Joffrey-Baratheon', 'Bronn', {'weight': 3}), ('Joffrey-Baratheon', 'Catelyn-Stark', {'weight': 3}), ('Joffrey-Baratheon', 'Cersei-Lannister', {'weight': 44}), ('Joffrey-Baratheon', 'Davos-Seaworth', {'weight': 10}), ('Joffrey-Baratheon', 'Dontos-Hollard', {'weight': 10}), ('Joffrey-Baratheon', 'Dunsen', {'weight': 6}), ('Joffrey-Baratheon', 'Eddard-Stark', {'weight': 3}), ('Joffrey-Baratheon', 'Garlan-Tyrell', {'weight': 6}), ('Joffrey-Baratheon', 'Gregor-Clegane', {'weight': 9}), ('Joffrey-Baratheon', 'High-Septon-(Tyrions)', {'weight': 6}), ('Joffrey-Baratheon', 'Ilyn-Payne', {'weight': 9}), ('Joffrey-Baratheon', 'Jon-Snow', {'weight': 4}), ('Joffrey-Baratheon', 'Kevan-Lannister', {'weight': 11}), ('Joffrey-Baratheon', 'Loras-Tyrell', {'weight': 12}), ('Joffrey-Baratheon', 'Mace-Tyrell', {'weight': 10}), ('Joffrey-Baratheon', 'Mance-Rayder', {'weight': 5}), ('Joffrey-Baratheon', 'Margaery-Tyrell', {'weight': 44}) ...
# [('Addam-Marbrand', 'Brynden-Tully', {'weight': 3}), ('Addam-Marbrand', 'Cersei-Lannister', {'weight': 3}), ('Addam-Marbrand', 'Jaime-Lannister', {'weight': 8}), ('Addam-Marbrand', 'Lyle-Crakehall', {'weight': 4}), ('Brynden-Tully', 'Catelyn-Stark', {'weight': 3}), ('Brynden-Tully', 'Daven-Lannister', {'weight': 3}), ('Brynden-Tully', 'Edmure-Tully', {'weight': 15}), ('Brynden-Tully', 'Edwyn-Frey', {'weight': 3}), ('Brynden-Tully', 'Emmon-Frey', {'weight': 7}), ('Brynden-Tully', 'Jaime-Lannister', {'weight': 18}), ('Brynden-Tully', 'Lyle-Crakehall', {'weight': 4}), ('Brynden-Tully', 'Ryman-Frey', {'weight': 3}), ('Cersei-Lannister', 'Aerys-II-Targaryen', {'weight': 3}), ('Cersei-Lannister', 'Aurane-Waters', {'weight': 9}), ('Cersei-Lannister', 'Baelor-I-Targaryen', {'weight': 5}), ('Cersei-Lannister', 'Balman-Byrch', {'weight': 7}), ('Cersei-Lannister', 'Blue-Bard', {'weight': 7}), ('Cersei-Lannister', 'Boros-Blount', {'weight': 3}), ('Cersei-Lannister', 'Bronn', {'weight': 4}), ('Cersei-Lannister', 'Dorcas', {'weight': 18}), ('Cersei-Lannister', 'Dunsen', {'weight': 4}), ('Cersei-Lannister', 'Eddard-Stark', {'weight': 3}), ('Cersei-Lannister', 'Falyse-Stokeworth', {'weight': 14}), ('Cersei-Lannister', 'Garlan-Tyrell', {'weight': 3}), ('Cersei-Lannister', 'Garth-Tyrell', {'weight': 3}), ('Cersei-Lannister', 'Gregor-Clegane', {'weight': 6}), ('Cersei-Lannister', 'Gyles-Rosby', {'weight': 18}), ('Cersei-Lannister', 'Harys-Swyft', {'weight': 4}), ('Cersei-Lannister', 'High-Septon-(Tyrions)', {'weight': 3}), ('Cersei-Lannister', 'High-Sparrow', {'weight': 24}), ('Cersei-Lannister', 'Ilyn-Payne', {'weight': 6}), ('Cersei-Lannister', 'Jaime-Lannister', {'weight': 49}), ('Cersei-Lannister', 'Jalabhar-Xho', {'weight': 3}), ('Cersei-Lannister', 'Jocelyn-Swyft', {'weight': 13}), ('Cersei-Lannister', 'Joffrey-Baratheon', {'weight': 21}), ('Cersei-Lannister', 'Jon-Snow', {'weight': 3}), ('Cersei-Lannister', 'Kevan-Lannister', {'weight': 9}), ('Cersei-Lannister', 'Lancel-Lannister', {'weight': 9}), ('Cersei-Lannister', 'Loras-Tyrell', {'weight': 24}), ('Cersei-Lannister', 'Mace-Tyrell', {'weight': 17}), ('Cersei-Lannister', 'Maegor-I-Targaryen', {'weight': 3}), ('Cersei-Lannister', 'Maggy', {'weight': 5}), ('Cersei-Lannister', 'Margaery-Tyrell', {'weight': 67}), ('Cersei-Lannister', 'Mark-Mullendore', {'weight': 3}), ('Cersei-Lannister', 'Melara-Hetherspoon', {'weight': 5}), ('Cersei-Lannister', 'Meryn-Trant', {'weight': 15}), ('Cersei-Lannister', 'Moon-Boy', {'weight': 5}), ('Cersei-Lannister', 'Myrcella-Baratheon', {'weight': 4}), ('Cersei-Lannister', 'Olenna-Redwyne', {'weight': 6}), ('Cersei-Lannister', 'Orton-Merryweather', {'weight': 9}), ('Cersei-Lannister', 'Osfryd-Kettleblack', {'weight': 8}), ('Cersei-Lannister', 'Osmund-Kettleblack', {'weight': 25}), ('Cersei-Lannister', 'Osney-Kettleblack', {'weight': 24}), ('Cersei-Lannister', 'Petyr-Baelish', {'weight': 7}), ('Cersei-Lannister', 'Pycelle', {'weight': 15}), ('Cersei-Lannister', 'Qyburn', {'weight': 27}), ('Cersei-Lannister', 'Rafford', {'weight': 4}), ('Cersei-Lannister', 'Raynard', {'weight': 3}), ('Cersei-Lannister', 'Rhaegar-Targaryen', {'weight': 5}), ('Cersei-Lannister', 'Robert-Baratheon', {'weight': 29}), ('Cersei-Lannister', 'Sansa-Stark', {'weight': 6}), ('Cersei-Lannister', 'Senelle', {'weight': 9}), ('Cersei-Lannister', 'Stannis-Baratheon', {'weight': 9}), ('Cersei-Lannister', 'Taena-of-Myr', {'weight': 46}), ('Cersei-Lannister', 'Tallad', {'weight': 4}), ('Cersei-Lannister', 'Tommen-Baratheon', {'weight': 80}), ('Cersei-Lannister', 'Tyrion-Lannister', {'weight': 36}), ('Cersei-Lannister', 'Tywin-Lannister', {'weight': 14}), ('Cersei-Lannister', 'Unella', {'weight': 3}), ('Cersei-Lannister', 'Varys', {'weight': 7}), ('Cersei-Lannister', 'Walder-Frey', {'weight': 5}), ('Jaime-Lannister', 'Aerys-II-Targaryen', {'weight': 6}), ('Jaime-Lannister', 'Amerei-Frey', {'weight': 6}), ('Jaime-Lannister', 'Balon-Swann', {'weight': 3}), ('Jaime-Lannister', 'Beric-Dondarrion', {' ...
# [('Aegon-I-Targaryen', 'Daenerys-Targaryen', {'weight': 4}), ('Daenerys-Targaryen', 'Aegon-Targaryen-(son-of-Rhaegar)', {'weight': 11}), ('Daenerys-Targaryen', 'Aggo', {'weight': 9}), ('Daenerys-Targaryen', 'Barristan-Selmy', {'weight': 75}), ('Daenerys-Targaryen', 'Barsena', {'weight': 4}), ('Daenerys-Targaryen', 'Belwas', {'weight': 13}), ('Daenerys-Targaryen', 'Ben-Plumm', {'weight': 14}), ('Daenerys-Targaryen', 'Benerro', {'weight': 3}), ('Daenerys-Targaryen', 'Bloodbeard', {'weight': 3}), ('Daenerys-Targaryen', 'Cersei-Lannister', {'weight': 3}), ('Daenerys-Targaryen', 'Cleon', {'weight': 9}), ('Daenerys-Targaryen', 'Cletus-Yronwood', {'weight': 3}), ('Daenerys-Targaryen', 'Daario-Naharis', {'weight': 50}), ('Daenerys-Targaryen', 'Daeron-II-Targaryen', {'weight': 3}), ('Daenerys-Targaryen', 'Doran-Martell', {'weight': 3}), ('Daenerys-Targaryen', 'Drogo', {'weight': 7}), ('Daenerys-Targaryen', 'Eroeh', {'weight': 3}), ('Daenerys-Targaryen', 'Ezzara', {'weight': 3}), ('Daenerys-Targaryen', 'Galazza-Galare', {'weight': 19}), ('Daenerys-Targaryen', 'Gerris-Drinkwater', {'weight': 15}), ('Daenerys-Targaryen', 'Ghael', {'weight': 5}), ('Daenerys-Targaryen', 'Grey-Worm', {'weight': 11}), ('Daenerys-Targaryen', 'Groleo', {'weight': 4}), ('Daenerys-Targaryen', 'Hero', {'weight': 5}), ('Daenerys-Targaryen', 'Hizdahr-zo-Loraq', {'weight': 96}), ('Daenerys-Targaryen', 'Illyrio-Mopatis', {'weight': 12}), ('Daenerys-Targaryen', 'Irri', {'weight': 25}), ('Daenerys-Targaryen', 'Jhiqui', {'weight': 15}), ('Daenerys-Targaryen', 'Jhogo', {'weight': 6}), ('Daenerys-Targaryen', 'Jon-Connington', {'weight': 6}), ('Daenerys-Targaryen', 'Jorah-Mormont', {'weight': 4}), ('Daenerys-Targaryen', 'Lysono-Maar', {'weight': 3}), ('Daenerys-Targaryen', 'Mace-Tyrell', {'weight': 3}), ('Daenerys-Targaryen', 'Marselen', {'weight': 3}), ('Daenerys-Targaryen', 'Meris', {'weight': 6}), ('Daenerys-Targaryen', 'Mezzara', {'weight': 4}), ('Daenerys-Targaryen', 'Miklaz', {'weight': 3}), ('Daenerys-Targaryen', 'Missandei', {'weight': 37}), ('Daenerys-Targaryen', 'Moqorro', {'weight': 3}), ('Daenerys-Targaryen', 'Penny', {'weight': 4}), ('Daenerys-Targaryen', 'Qavo-Nogarys', {'weight': 5}), ('Daenerys-Targaryen', 'Qezza', {'weight': 6}), ('Daenerys-Targaryen', 'Quaithe', {'weight': 6}), ('Daenerys-Targaryen', 'Quentyn-Martell', {'weight': 58}), ('Daenerys-Targaryen', 'Rakharo', {'weight': 7}), ('Daenerys-Targaryen', 'Reznak-mo-Reznak', {'weight': 19}), ('Daenerys-Targaryen', 'Rhaegar-Targaryen', {'weight': 10}), ('Daenerys-Targaryen', 'Robert-Baratheon', {'weight': 3}), ('Daenerys-Targaryen', 'Skahaz-mo-Kandaq', {'weight': 33}), ('Daenerys-Targaryen', 'Spotted-Cat', {'weight': 3}), ('Daenerys-Targaryen', 'Symon-Stripeback', {'weight': 4}), ('Daenerys-Targaryen', 'Tattered-Prince', {'weight': 4}), ('Daenerys-Targaryen', 'Tyrion-Lannister', {'weight': 17}), ('Daenerys-Targaryen', 'Varys', {'weight': 3}), ('Daenerys-Targaryen', 'Victarion-Greyjoy', {'weight': 7}), ('Daenerys-Targaryen', 'Viserys-Targaryen', {'weight': 7}), ('Daenerys-Targaryen', 'Xaro-Xhoan-Daxos', {'weight': 16}), ('Daenerys-Targaryen', 'Yurkhaz-zo-Yunzak', {'weight': 4}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Elia-Martell', {'weight': 4}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Franklyn-Flowers', {'weight': 3}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Haldon', {'weight': 14}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Harry-Strickland', {'weight': 9}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Jon-Connington', {'weight': 16}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Lemore', {'weight': 10}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Rhaegar-Targaryen', {'weight': 9}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Rhaenys-Targaryen-(daughter-of-Rhaegar)', {'weight': 4}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Rolly-Duckfield', {'weight': 11}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Tyrion-Lannister', {'weight': 23}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'Tywin-Lannister', {'weight': 3}), ('Aegon-Targaryen-(son-of-Rhaegar)', 'V ...

# %% [markdown]
# ## Finding important nodes (characters)
#
# Let's use and compare different centralities measures we saw earlier to identify importance of nodes in this network. There is no one right way of calaculating it, every approach has a different meaning.
#
# ## Calculate Degree Centrality
# Degree centrality which is defined by degree of a node (number of neighbors) divided by a noramlizing factor n-1 where n is the number of nodes.
#
# - __Find the neighbours of '**Catelyn-Stark**' from book 1.__

# %%
# Neighbors for catelyn stark
catelyn_neighbors = [n for n in graphs[0].neighbors('Catelyn-Stark')]
print(catelyn_neighbors)
# Out:
# ['Arya-Stark', 'Bran-Stark', 'Bronn', 'Brynden-Tully', 'Cersei-Lannister', 'Colemon', 'Donnel-Waynwood', 'Eddard-Stark', 'Edmure-Tully', 'Eon-Hunter', 'Hallis-Mollen', 'Hoster-Tully', 'Jaime-Lannister', 'Joffrey-Baratheon', 'Jon-Arryn', 'Jon-Snow', 'Jon-Umber-(Greatjon)', 'Luwin', 'Lysa-Arryn', 'Marillion', 'Masha-Heddle', 'Moreo-Tumitis', 'Mya-Stone', 'Mychel-Redfort', 'Nestor-Royce', 'Petyr-Baelish', 'Rickard-Karstark', 'Rickon-Stark', 'Robb-Stark', 'Robert-Arryn', 'Robert-Baratheon', 'Rodrik-Cassel', 'Sansa-Stark', 'Stevron-Frey', 'Theon-Greyjoy', 'Tyrion-Lannister', 'Tytos-Blackwood', 'Tywin-Lannister', 'Vardis-Egen', 'Varys', 'Walder-Frey', 'Wendel-Manderly', 'Willis-Wode']

# %% [markdown]
#  `nx.degree_centrality(graph)` returns a dictionary where keys are the nodes and values are the corresponding degree centrality.
#
# - __Find the five most and least important characters from book 1 according to degree centrality__

# %%
# Five most important characters from book 1 according to degree centrality
centralities = nx.degree_centrality(graphs[0])
cent_df = pd.Series(centralities).sort_values(ascending = False)
cent_df.head()
# Out:
# Eddard-Stark        0.354839
# Robert-Baratheon    0.268817
# Tyrion-Lannister    0.247312
# Catelyn-Stark       0.231183
# Jon-Snow            0.198925
# dtype: float64

# %%
# Five least important characters from book 1 according to degree centrality
cent_df.tail()
# Out:
# Jacks              0.005376
# Joss               0.005376
# Porther            0.005376
# Tobho-Mott         0.005376
# Ulf-son-of-Umar    0.005376
# dtype: float64

# %% [markdown]
# - __Plot and explain histogram from degree centrality values, calculated from book 1, and comment on the output__

# %%
# Plot a histogram of degree centrality
cent_df.plot(kind='hist')

# %%
# Your observations here

# %% [markdown]
# ##  Weighted Degree Centrality
#
# - Create a new centrality measure as a function, `weighted_degree_centrality(Graph)` which takes in Graph and the returns a weighted degree centrality dictionary.
#
# [Refer to this paper to get an insight into this approacj](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0165781)
#
# Weighted degree is calculated by:
#
# 1) __Sum the weight of the all edges of a node__
#
# 2) __Normalize the weighted degree by the total weight of the graph i.e. sum of weighted degrees of all nodes__
#
# 3) __Calculated weighted degree centrality for book 1 using this function__

# %%
def weighted_degree_centrality(G):
    node_weights = pd.DataFrame()
    for node in G.nodes():
        weight_sum = 0
        for s, t, w in G.edges(node, data = 'weight'):
            weight_sum += w
        node_weights = node_weights.append(pd.DataFrame({'node': node, 'weight_deg': weight_sum}, index = [0]), ignore_index = True)
    node_weights['norm_weighted_deg'] = node_weights['weight_deg']/node_weights['weight_deg'].sum()
    node_weights.drop('weight_deg', axis = 1)
    node_weights.set_index('node')
    return pd.Series(data = list(node_weights['norm_weighted_deg']), index = node_weights['node']).to_dict()

# %%
# Uncomment below to run
G1 = graphs[0] 
print(weighted_degree_centrality(G1))
plt.hist(list(weighted_degree_centrality(G1).values()))
plt.show()
# Out:
# {'Addam-Marbrand': 0.0006109150149334781, 'Jaime-Lannister': 0.01635894651099647, 'Tywin-Lannister': 0.012286179744773282, 'Aegon-I-Targaryen': 0.0006109150149334781, 'Daenerys-Targaryen': 0.030070594623947868, 'Eddard-Stark': 0.08715720879717621, 'Aemon-Targaryen-(Maester-Aemon)': 0.005023079011675265, 'Alliser-Thorne': 0.005430355688297583, 'Bowen-Marsh': 0.0019006244909041542, 'Chett': 0.001289709475970676, 'Clydas': 0.00033939723051859896, 'Jeor-Mormont': 0.012286179744773282, 'Jon-Snow': 0.05321748574531632, 'Samwell-Tarly': 0.01004615802335053, 'Aerys-II-Targaryen': 0.0025115395058376323, 'Brandon-Stark': 0.0027830572902525115, 'Gerold-Hightower': 0.0011539505837632365, 'Jon-Arryn': 0.011471626391528645, 'Robert-Baratheon': 0.06387455878360032, 'Aggo': 0.0024436600597339125, 'Drogo': 0.017377138202552267, 'Jhogo': 0.002918816182459951, 'Jorah-Mormont': 0.010453434699972848, 'Quaro': 0.0014254683681781156, 'Rakharo': 0.001629106706489275, 'Albett': 0.0007466739071409177, 'Halder': 0.0038012489818083084, 'Rast': 0.0017648655986967146, 'Grenn': 0.005769752918816182, 'Pypar': 0.007263100733098018, 'Tyrion-Lannister': 0.044121639967417865, 'Alyn': 0.0021721422753190334, 'Harwin': 0.0012218300298669563, 'Jory-Cassel': 0.010317675807765408, 'Tomard': 0.0028509367363562313, 'Arthur-Dayne': 0.00027151778441487917, 'Arya-Stark': 0.02918816182459951, 'Benjen-Stark': 0.0070594623947868584, 'Bran-Stark': 0.03604398588107521, 'Catelyn-Stark': 0.03529731197393429, 'Cersei-Lannister': 0.028780885147977192, 'Desmond': 0.00047515612272603855, 'Ilyn-Payne': 0.002918816182459951, 'Jeyne-Poole': 0.003665490089600869, 'Joffrey-Baratheon': 0.028645126255769753, 'Meryn-Trant': 0.0024436600597339125, 'Mordane': 0.00957100190062449, 'Mycah': 0.0033939723051859896, 'Myrcella-Baratheon': 0.003665490089600869, 'Petyr-Baelish': 0.021246266630464295, 'Rickon-Stark': 0.00665218571816454, 'Robb-Stark': 0.03502579418951941, 'Rodrik-Cassel': 0.008417051316861254, 'Sandor-Clegane': 0.009163725224002172, 'Sansa-Stark': 0.03699429812652729, 'Syrio-Forel': 0.0021042628292153136, 'Tommen-Baratheon': 0.0025115395058376323, 'Vayon-Poole': 0.0019006244909041542, 'Yoren': 0.002240021721422753, 'Arys-Oakheart': 0.00020363833831115938, 'Balon-Greyjoy': 0.00047515612272603855, 'Balon-Swann': 0.00040727667662231876, 'Renly-Baratheon': 0.012625576975291881, 'Barristan-Selmy': 0.00970676079283193, 'Boros-Blount': 0.0017648655986967146, 'Pycelle': 0.010181916915557969, 'Varys': 0.015680152049959272, 'Jaremy-Rykker': 0.001629106706489275, 'Luwin': 0.014254683681781156, 'Mance-Rayder': 0.00020363833831115938, 'Theon-Greyjoy': 0.009027966331794732, 'Waymar-Royce': 0.002307901167526473, 'Beric-Dondarrion': 0.0019006244909041542, 'Gregor-Clegane': 0.005023079011675265, 'Loras-Tyrell': 0.005294596796090144, 'Thoros-of-Myr': 0.00033939723051859896, 'Hali': 0.00020363833831115938, 'Hallis-Mollen': 0.0025115395058376323, 'Hodor': 0.0035297311973934292, 'Hullen': 0.0013575889220743959, 'Joseth': 0.00047515612272603855, 'Nan': 0.002240021721422753, 'Osha': 0.0021042628292153136, 'Rickard-Karstark': 0.0031224545207711105, 'Rickard-Stark': 0.00047515612272603855, 'Stiv': 0.00047515612272603855, 'Lyanna-Stark': 0.0024436600597339125, 'Bronn': 0.007398859625305457, 'Chiggen': 0.0010860711376595167, 'Marillion': 0.001968503937007874, 'Shae': 0.0010181916915557969, 'Shagga': 0.002986695628563671, 'Vardis-Egen': 0.0025115395058376323, 'Willis-Wode': 0.0019006244909041542, 'Brynden-Tully': 0.004683681781156666, 'Edmure-Tully': 0.00325821341297855, 'Hoster-Tully': 0.001629106706489275, 'Lysa-Arryn': 0.009367363562313331, 'Nestor-Royce': 0.00040727667662231876, 'Walder-Frey': 0.0027830572902525115, 'Colemon': 0.00047515612272603855, 'Donnel-Waynwood': 0.00020363833831115938, 'Eon-Hunter': 0.0006109150149334781, 'Jon-Umber-(Greatjon)': 0.002647298398045072, 'Masha-Heddle': 0.00033939723051859896, 'Moreo-Tumitis': 0.00020363833831115938, 'Mya-Stone': 0.0006109150149334781, 'Mychel-Redfort': 0. ...

# %% [markdown]
# - __Get the top 10 characters from book 1, based on weighted degree centrality and compare with the results of simple degree centrality. Record your observations below__

# %%
# Weighted DC
weighted_dc = weighted_degree_centrality(G1)
weighted_dc_df = pd.Series(weighted_dc).sort_values(ascending = False)
weighted_dc_df.head(10)
# Out:
# Eddard-Stark          0.087157
# Robert-Baratheon      0.063875
# Jon-Snow              0.053217
# Tyrion-Lannister      0.044122
# Sansa-Stark           0.036994
# Bran-Stark            0.036044
# Catelyn-Stark         0.035297
# Robb-Stark            0.035026
# Daenerys-Targaryen    0.030071
# Arya-Stark            0.029188
# dtype: float64

# %%
# Un-weighted DC
cent_df.head(10)
# Out:
# Eddard-Stark         0.354839
# Robert-Baratheon     0.268817
# Tyrion-Lannister     0.247312
# Catelyn-Stark        0.231183
# Jon-Snow             0.198925
# Robb-Stark           0.188172
# Sansa-Stark          0.188172
# Bran-Stark           0.172043
# Joffrey-Baratheon    0.161290
# Cersei-Lannister     0.161290
# dtype: float64

# %%
# Your observations here

# %% [markdown]
# - __ Confirm that sum of weighted degree centralitity value for all nodes sum up to 1 i.e. normalization__

# %%
# Uncomment to run 

#sum(list(weighted_degree_centrality(G1).values()))
# Out:
# 1.0000000000000002

# %% [markdown]
# ## Betweenness centrality
#
# - __Calculate the weighted and un-weighted "Betweenness" centrality for book 2, and compare top ten characters as above__
# - __Comment on the results__

# %%
G2 = graphs[1]
# Unweighted Betweenness Centrality
sorted(nx.betweenness_centrality(G2).items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Arya-Stark', 0.1881116846731781),
#  ('Jon-Snow', 0.17443976935054054),
#  ('Robb-Stark', 0.1649406213117506),
#  ('Tyrion-Lannister', 0.15532375650368552),
#  ('Robert-Baratheon', 0.15374366220396257),
#  ('Theon-Greyjoy', 0.14439534223860254),
#  ('Stannis-Baratheon', 0.11951360907930143),
#  ('Bran-Stark', 0.11323494837768544),
#  ('Catelyn-Stark', 0.11104383596371503),
#  ('Joffrey-Baratheon', 0.09078190285323477)]

# %%
# Weighted Betweenness similarity 
sorted(nx.betweenness_centrality(G2, weight='weight').items(), key=lambda x:x[1], reverse=True)[0:10]
# Out:
# [('Jaime-Lannister', 0.1720314977622008),
#  ('Robert-Baratheon', 0.1569434521882266),
#  ('Jon-Snow', 0.1533306704422441),
#  ('Arya-Stark', 0.1368247670279162),
#  ('Robb-Stark', 0.12885596466494134),
#  ('Theon-Greyjoy', 0.11499641632661273),
#  ('Stannis-Baratheon', 0.11446952689374187),
#  ('Catelyn-Stark', 0.10955994658374536),
#  ('Joffrey-Baratheon', 0.09911495273679691),
#  ('Tyrion-Lannister', 0.09893402528458174)]

# %%
# Your observations here

# %% [markdown]
# ## Is there a correlation between node centrality measures?
#
# Well, lets find out.
#
#
# - __Find the correlation between following:__
#     - Weighted Degree
#     - Closeness
#     - Weighted Betweenness
#     - Weighted Eigenvector
# - __Use book 1 for the analysis (You may choose other books as well)__
# - __Calculate correlation matrix and visualize the results for all characters__
# - __Comment on the results__

# %%
# Create a dataframe with 4 centrality measures, for all characters
deg = pd.Series(weighted_degree_centrality(G1))
print(deg.head())
clsns = pd.Series(nx.closeness_centrality(G1))
bet = pd.Series(nx.betweenness_centrality(G1, weight = 'weight'))
eig = pd.Series(nx.eigenvector_centrality(G1, weight = 'weight'))
df = pd.concat([deg, clsns, bet, eig], axis=1)
df.columns = ['Degree', 'Closeness', 'Betweenness', 'Eigenvector']
df.head()
# Out:
# Addam-Marbrand        0.000611
# Jaime-Lannister       0.016359
# Tywin-Lannister       0.012286
# Aegon-I-Targaryen     0.000611
# Daenerys-Targaryen    0.030071
# dtype: float64
#                       Degree  Closeness  Betweenness  Eigenvector
# Addam-Marbrand      0.000611   0.323478     0.000000     0.001551
# Jaime-Lannister     0.016359   0.461538     0.077451     0.103790
# Tywin-Lannister     0.012286   0.449275     0.041211     0.068416
# Aegon-I-Targaryen   0.000611   0.376518     0.000000     0.005096
# Daenerys-Targaryen  0.030071   0.405229     0.034182     0.025726

# %%
# plot the measures as lines to see if they correlate
df.plot(figsize = (15, 8))

# %%
# calculate Correlation matrix
df.corr()
# Out:
#                Degree  Closeness  Betweenness  Eigenvector
# Degree       1.000000   0.713617     0.857222     0.922520
# Closeness    0.713617   1.000000     0.675276     0.697500
# Betweenness  0.857222   0.675276     1.000000     0.805318
# Eigenvector  0.922520   0.697500     0.805318     1.000000

# %%
# Your observations here

# %% [markdown]
# ## Character Evolution : Bring the the rest of series
#
# By Studying the change in centrality throughout the series, we can create an evolution of characters as the story progresses.
#
# - __Calculate the weighted degree centrality for all five books (edge lists), and save your results in a dataframe__
#
# Hint: Fill nans with zero for values that can not be calculated  due to being extremely small

# %%
# Create a character evolution dataframe based on weighted degree centrality from all books
degs = []
for G in graphs:
    degs.append(pd.Series(weighted_degree_centrality(G)))
deg_df = pd.DataFrame(degs[0], columns = ['Book 1'])
for i in range(1,5):
    deg_df = pd.merge(deg_df, degs[i].to_frame(name = 'Book {}'.format(i+1)), how = 'outer', left_index=True, right_index=True)
# Fill Nans and view contents
deg_df = deg_df.fillna(0).sort_index().T
deg_df.head()
# Out:
#         Addam-Marbrand  Aegon-Frey-(son-of-Stevron)  Aegon-I-Targaryen  \
# Book 1        0.000611                     0.000000           0.000611
# Book 2        0.000000                     0.000000           0.001336
# Book 3        0.001711                     0.001062           0.000649
# Book 4        0.001908                     0.000000           0.000000
# Book 5        0.000000                     0.000000           0.000350
#
#         Aegon-Targaryen-(son-of-Rhaegar)  Aegon-V-Targaryen  \
# Book 1                          0.000000           0.000000
# Book 2                          0.000000           0.000236
# Book 3                          0.000177           0.000000
# Book 4                          0.000318           0.000318
# Book 5                          0.011386           0.000000
#
#         Aemon-Targaryen-(Dragonknight)  Aemon-Targaryen-(Maester-Aemon)  \
# Book 1                        0.000000                         0.005023
# Book 2                        0.000000                         0.002673
# Book 3                        0.000177                         0.009083
# Book 4                        0.000000                         0.009752
# Book 5                        0.000000                         0.003591
#
#         Aenys-Frey  Aeron-Greyjoy  Aerys-I-Targaryen    ...     Yellow-Dick  \
# Book 1    0.000000       0.000000           0.000000    ...        0.000000
# Book 2    0.000472       0.001730           0.000236    ...        0.000000
# Book 3    0.000000       0.000000           0.000000    ...        0.000000
# Book 4    0.000000       0.012932           0.000000    ...        0.000000
# Book 5    0.001139       0.000613           0.000000    ...        0.001314
#
#         Yezzan-zo-Qaggaz   Ygritte  Yohn-Royce    Yoren  Yorko-Terys  \
# Book 1          0.000000  0.000000    0.000000  0.00224     0.000000
# Book 2          0.000000  0.001887    0.000000  0.00684     0.000000
# Book 3          0.000000  0.007314    0.000177  0.00000     0.000000
# Book 4          0.000000  0.000000    0.003922  0.00000     0.000636
# Book 5          0.004204  0.001489    0.000000  0.00000     0.000000
#
#           Ysilla  Yurkhaz-zo-Yunzak       Zei     Zollo
# Book 1  0.000000            0.00000  0.000000  0.000000
# Book 2  0.000000            0.00000  0.000000  0.000000
# Book 3  0.000000            0.00000  0.000177  0.000472
# Book 4  0.000000            0.00000  0.000000  0.000636
# Book 5  0.004029            0.00035  0.000000  0.000000
#
# [5 rows x 796 columns]

# %% [markdown]
# - __Identify top 10 characters i.e. having 10 highest degree centrality values, from `evol_degree_df` and create a new dataframe with their names and centrality value__

# %%
deg_df.max(axis=0).sort_values(ascending=False)[0:10]
# Out:
# Eddard-Stark          0.087157
# Cersei-Lannister      0.082998
# Jon-Snow              0.066649
# Tyrion-Lannister      0.065173
# Robert-Baratheon      0.063875
# Daenerys-Targaryen    0.063146
# Jaime-Lannister       0.059148
# Joffrey-Baratheon     0.049450
# Bran-Stark            0.038208
# Sansa-Stark           0.036994
# dtype: float64

# %% [markdown]
# - __Plot the evolution of weighted degree centrality of the above characters over the 5 books__
# - __Comment on your answer__

# %%
chars = list(deg_df.max(axis=0).sort_values(ascending=False)[0:10].index)
ev_df = deg_df[chars]
ev_df.plot(figsize = (15,8))

# %%
# Your observations here

# %% [markdown]
# #### Repeat Above for Weighted Betweenness Centrality

# %%
bets = []
for G in graphs:
    bets.append(pd.Series(nx.betweenness_centrality(G, weight = 'weight')))
bet_df = pd.DataFrame(bets[0], columns = ['Book 1'])
for i in range(1,5):
    bet_df = pd.merge(bet_df, bets[i].to_frame(name = 'Book {}'.format(i+1)), how = 'outer', left_index=True, right_index=True)
# Fill Nans and view contents
bet_df = bet_df.fillna(0).sort_index().T

chars = list(bet_df.max(axis=0).sort_values(ascending=False)[0:10].index)
ev_df = bet_df[chars]
ev_df.plot(figsize = (15,8))

# %%
# Record Your observations here

# %% [markdown]
# ## Level Up: Visualize the Graphs (optional)
#
# - Use the techniques seen so far to visualize and customize the graphs
# - Study the shapes of the graphs in terms of spread , clusters etc and see if you can identify any links to the actual books (or the TV series)

# %% [markdown]
# ## Summary
#
# In this lab, we looked at different centrality measures of the graph data for the ASIOF dataset. We also compared these measures to see how they correlate with each other. We also saw in practice, the difference between taking the weighted centrality measures and how it may effect the results.
